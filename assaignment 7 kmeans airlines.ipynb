# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = pd.read_excel("C:\\Users\\SINDHUJA\\Downloads\\EastWestAirlines.xlsx",sheet_name= 'data')

# %%
data.head(10)
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
# 5    6    16420           0          1          1          1            0
# 6    7    84914           0          3          1          1        27482
# 7    8    20856           0          1          1          1         5250
# 8    9   443003           0          3          2          1         1753
# 9   10   104860           0          3          1          1        28426
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
# 5            0                  0                0               6942       0
# 6           25                  0                0               6994       0
# 7            4                250                1               6938       1
# 8           43               3850               12               6948       1
# 9           28               1150                3               6931       1

# %%
data.shape
# Out:
# (3999, 12)

# %%
data.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# min       1.000000       0.000000      0.00000           0.000000
# 25%       1.000000    1250.000000      3.00000           0.000000
# 50%       1.000000    7171.000000     12.00000           0.000000
# 75%       1.000000   23800.500000     17.00000         311.000000
# max       5.000000  263685.000000     86.00000       30817.000000
#
#        Flight_trans_12  Days_since_enroll       Award?
# count      3999.000000         3999.00000  3999.000000
# mean          1.373593         4118.55939     0.370343
# std           3.793172         2065.13454     0.482957
# min           0.000000            2.00000     0.000000
# 25%           0.000000         2330.00000     0.000000
# 50%           0.000000         4096.00000     0.000000
# 75%           1.000000         5790.50000     1.000000
# max          53.000000         8296.00000     1.000000

# %%
data.mean()
# Out:
# ID#                   2014.819455
# Balance              73601.327582
# Qual_miles             144.114529
# cc1_miles                2.059515
# cc2_miles                1.014504
# cc3_miles                1.012253
# Bonus_miles          17144.846212
# Bonus_trans             11.601900
# Flight_miles_12mo      460.055764
# Flight_trans_12          1.373593
# Days_since_enroll     4118.559390
# Award?                   0.370343
# dtype: float64

# %%
data.median()
# Out:
# ID#                   2016.0
# Balance              43097.0
# Qual_miles               0.0
# cc1_miles                1.0
# cc2_miles                1.0
# cc3_miles                1.0
# Bonus_miles           7171.0
# Bonus_trans             12.0
# Flight_miles_12mo        0.0
# Flight_trans_12          0.0
# Days_since_enroll     4096.0
# Award?                   0.0
# dtype: float64

# %%
data.var()
# Out:
# ID#                  1.347374e+06
# Balance              1.015573e+10
# Qual_miles           5.985557e+05
# cc1_miles            1.895907e+00
# cc2_miles            2.180060e-02
# cc3_miles            3.811896e-02
# Bonus_miles          5.832692e+08
# Bonus_trans          9.223317e+01
# Flight_miles_12mo    1.960586e+06
# Flight_trans_12      1.438816e+01
# Days_since_enroll    4.264781e+06
# Award?               2.332473e-01
# dtype: float64

# %%
data.std()
# Out:
# ID#                    1160.764358
# Balance              100775.664958
# Qual_miles              773.663804
# cc1_miles                 1.376919
# cc2_miles                 0.147650
# cc3_miles                 0.195241
# Bonus_miles           24150.967826
# Bonus_trans               9.603810
# Flight_miles_12mo      1400.209171
# Flight_trans_12           3.793172
# Days_since_enroll      2065.134540
# Award?                    0.482957
# dtype: float64

# %%
data.skew()
# Out:
# ID#                  -0.003343
# Balance               5.004187
# Qual_miles            7.512395
# cc1_miles             0.857569
# cc2_miles            11.210459
# cc3_miles            17.195532
# Bonus_miles           2.842093
# Bonus_trans           1.157362
# Flight_miles_12mo     7.451666
# Flight_trans_12       5.490461
# Days_since_enroll     0.120174
# Award?                0.537200
# dtype: float64

# %%
data.kurt()
# Out:
# ID#                   -1.199648
# Balance               44.157932
# Qual_miles            67.689351
# cc1_miles             -0.748508
# cc2_miles            133.786489
# cc3_miles            308.654728
# Bonus_miles           13.630489
# Bonus_trans            2.745737
# Flight_miles_12mo     94.761019
# Flight_trans_12       42.978152
# Days_since_enroll     -0.967505
# Award?                -1.712272
# dtype: float64

# %%
data.dtypes
# Out:
# ID#                  int64
# Balance              int64
# Qual_miles           int64
# cc1_miles            int64
# cc2_miles            int64
# cc3_miles            int64
# Bonus_miles          int64
# Bonus_trans          int64
# Flight_miles_12mo    int64
# Flight_trans_12      int64
# Days_since_enroll    int64
# Award?               int64
# dtype: object

# %%
data.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %%
data.shape
# Out:
# (3999, 12)

# %%
data.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
#Normalization of the Data
def norm_df(i):
    x = (i-i.min())/(i.min()-i.max())
    return(x)

# %%
normal_data=norm_df(data)
normal_data
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0    -0.000000 -0.016508        -0.0      -0.00       -0.0       -0.0
# 1    -0.000249 -0.011288        -0.0      -0.00       -0.0       -0.0
# 2    -0.000498 -0.024257        -0.0      -0.00       -0.0       -0.0
# 3    -0.000746 -0.008667        -0.0      -0.00       -0.0       -0.0
# 4    -0.000995 -0.057338        -0.0      -0.75       -0.0       -0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994 -0.999005 -0.010837        -0.0      -0.00       -0.0       -0.0
# 3995 -0.999254 -0.037766        -0.0      -0.00       -0.0       -0.0
# 3996 -0.999502 -0.043169        -0.0      -0.50       -0.0       -0.0
# 3997 -0.999751 -0.032202        -0.0      -0.00       -0.0       -0.0
# 3998 -1.000000 -0.001769        -0.0      -0.00       -0.0       -0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0       -0.000660    -0.011628          -0.000000        -0.000000
# 1       -0.000815    -0.023256          -0.000000        -0.000000
# 2       -0.015636    -0.046512          -0.000000        -0.000000
# 3       -0.001896    -0.011628          -0.000000        -0.000000
# 4       -0.164211    -0.302326          -0.067398        -0.075472
# ...           ...          ...                ...              ...
# 3994    -0.032330    -0.046512          -0.006490        -0.018868
# 3995    -0.003720    -0.058140          -0.000000        -0.000000
# 3996    -0.096505    -0.093023          -0.000000        -0.000000
# 3997    -0.001896    -0.011628          -0.016225        -0.018868
# 3998    -0.000000    -0.000000          -0.000000        -0.000000
#
#       Days_since_enroll  Award?
# 0             -0.843742    -0.0
# 1             -0.839884    -0.0
# 2             -0.847842    -0.0
# 3             -0.837955    -0.0
# 4             -0.835905    -1.0
# ...                 ...     ...
# 3994          -0.168917    -1.0
# 3995          -0.167953    -1.0
# 3996          -0.168797    -1.0
# 3997          -0.168676    -0.0
# 3998          -0.168314    -0.0
#
# [3999 rows x 12 columns]

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
for k in range(1,11):
    clf=KMeans(n_clusters=k)
    clf.fit(normal_data)
    wcss.append(clf.inertia_)
plt.plot(range(1,11),wcss)
plt.title("Elbow Method")
plt.xlabel("WCSS")
plt.ylabel("No of Clusters")
plt.show()

# %% [markdown]
# Here we Assume that k-value is to  be 5

# %%
model1=KMeans(n_clusters=5)
model1.fit(normal_data)
model1.labels_
# Out:
# array([0, 0, 0, ..., 4, 2, 2])

# %%
model1.labels_.shape
# Out:
# (3999,)

# %%
normal_data['Clusters']=model1.labels_

# %%
normal_data
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0    -0.000000 -0.016508        -0.0      -0.00       -0.0       -0.0
# 1    -0.000249 -0.011288        -0.0      -0.00       -0.0       -0.0
# 2    -0.000498 -0.024257        -0.0      -0.00       -0.0       -0.0
# 3    -0.000746 -0.008667        -0.0      -0.00       -0.0       -0.0
# 4    -0.000995 -0.057338        -0.0      -0.75       -0.0       -0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994 -0.999005 -0.010837        -0.0      -0.00       -0.0       -0.0
# 3995 -0.999254 -0.037766        -0.0      -0.00       -0.0       -0.0
# 3996 -0.999502 -0.043169        -0.0      -0.50       -0.0       -0.0
# 3997 -0.999751 -0.032202        -0.0      -0.00       -0.0       -0.0
# 3998 -1.000000 -0.001769        -0.0      -0.00       -0.0       -0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0       -0.000660    -0.011628          -0.000000        -0.000000
# 1       -0.000815    -0.023256          -0.000000        -0.000000
# 2       -0.015636    -0.046512          -0.000000        -0.000000
# 3       -0.001896    -0.011628          -0.000000        -0.000000
# 4       -0.164211    -0.302326          -0.067398        -0.075472
# ...           ...          ...                ...              ...
# 3994    -0.032330    -0.046512          -0.006490        -0.018868
# 3995    -0.003720    -0.058140          -0.000000        -0.000000
# 3996    -0.096505    -0.093023          -0.000000        -0.000000
# 3997    -0.001896    -0.011628          -0.016225        -0.018868
# 3998    -0.000000    -0.000000          -0.000000        -0.000000
#
#       Days_since_enroll  Award?  Clusters
# 0             -0.843742    -0.0         0
# 1             -0.839884    -0.0         0
# 2             -0.847842    -0.0         0
# 3             -0.837955    -0.0         0
# 4             -0.835905    -1.0         1
# ...                 ...     ...       ...
# 3994          -0.168917    -1.0         4
# 3995          -0.167953    -1.0         4
# 3996          -0.168797    -1.0         4
# 3997          -0.168676    -0.0         2
# 3998          -0.168314    -0.0         2
#
# [3999 rows x 13 columns]

# %%
model1.inertia_
# Out:
# 536.2058077038275

# %%
model1.cluster_centers_
# Out:
# array([[-2.89912227e-01, -2.90759252e-02, -8.13008130e-03,
#         -2.87456446e-02, -8.71080139e-03, -2.90360046e-04,
#         -1.27773616e-02, -7.90319531e-02, -7.84858743e-03,
#         -1.35647448e-02, -6.72153050e-01, -1.27675648e-15],
#        [-3.42945649e-01, -6.97214035e-02, -1.80181623e-02,
#         -7.68505080e-01, -7.25689405e-04, -7.61973875e-03,
#         -1.88969989e-01, -2.42582779e-01, -2.53419773e-02,
#         -4.46093600e-02, -6.33971854e-01, -1.00000000e+00],
#        [-7.99889119e-01, -2.08427126e-02, -8.45630176e-03,
#         -5.20179372e-02, -8.52017937e-03, -1.56950673e-03,
#         -1.67911383e-02, -8.10512045e-02, -6.96072039e-03,
#         -1.13207547e-02, -2.39576397e-01, -4.82947016e-15],
#        [-4.04219218e-01, -7.39125070e-02, -6.19557460e-03,
#         -6.66512915e-01, -9.22509225e-04, -6.45756458e-03,
#         -1.25357131e-01, -2.01621900e-01, -7.32672950e-03,
#         -1.23581424e-02, -5.78347661e-01,  3.88578059e-16],
#        [-5.13172144e-01, -4.57984220e-02, -2.46153226e-02,
#         -1.08270202e-01, -1.38888889e-02, -1.89393939e-03,
#         -4.05913957e-02, -1.32135307e-01, -2.99861958e-02,
#         -5.29111873e-02, -4.90783315e-01, -1.00000000e+00]])

# %%
data.iloc[:,0:].groupby(normal_data['Clusters']).mean()
# Out:
#                   ID#        Balance  Qual_miles  cc1_miles  cc2_miles  \
# Clusters
# 0         1167.635731   49591.404872   90.529002   1.116009   1.017401
# 1         1379.641509  118863.698113  200.866473   4.074020   1.001451
# 2         3217.832884   35476.043127   94.440252   1.205750   1.017071
# 3         1628.158379  125899.655617   68.941068   3.664825   1.001842
# 4         2063.952020   78078.890152  274.411616   1.433081   1.027778
#
#           cc3_miles   Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# Clusters
# 0          1.001160   3376.904872     6.814385         242.636891
# 1          1.030479  49828.551524    20.862119         780.963716
# 2          1.006289   4406.252471     6.948787         213.902965
# 3          1.025783  33035.488029    17.337017         225.740331
# 4          1.007576  10703.342172    11.363636         924.084596
#
#           Flight_trans_12  Days_since_enroll  Award?
# Clusters
# 0                0.721578        5574.878190     0.0
# 1                2.364296        5260.162554     1.0
# 2                0.597484        1987.256963     0.0
# 3                0.655617        4793.812155     0.0
# 4                2.804293        4072.556818     1.0
